# %%
import os
import csv
import json
from elasticsearch import Elasticsearch

# %%
csv_path="/var/www/html/Salla/customer_transcations_raw.csv"
client = Elasticsearch("http://3.125.9.240:9221/")
data = []
counter = 0

# %%
with open(csv_path) as csv_file:
    reader = csv.DictReader(csv_file)
    for row in reader:
        counter = counter + 1
        data.append({"index": {"_index": "profiles22", "_id": row['product_id']}})
        data.append(row)
        if counter%500==0:
            resp = client.bulk(body=data)
            data = []
# Out:
# /tmp/ipykernel_2405/1685670495.py:8: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use the 'operations' parameter. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   resp = client.bulk(body=data)
# {'took': 9, 'errors': False, 'items': [{'index': {'_index': 'profiles22', '_id': '13690016', '_version': 12246, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 743798, '_primary_term': 1, 'status': 200}}, {'index': {'_index': 'profiles22', '_id': '11495803', '_version': 889, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 743799, '_primary_term': 1, 'status': 200}}, {'index': {'_index': 'profiles22', '_id': '39961752', '_version': 111, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 743800, '_primary_term': 1, 'status': 200}}, {'index': {'_index': 'profiles22', '_id': '40249527', '_version': 3610, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 743801, '_primary_term': 1, 'status': 200}}, {'index': {'_index': 'profiles22', '_id': '34462642', '_version': 10, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 743802, '_primary_term': 1, 'status': 200}}, {'index': {'_index': 'profiles22', '_id': '38326571', '_version': 16, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 743803, '_primary_term': 1, 'status': 200}}, {'index': {'_index': 'profiles22', '_id': '38747399', '_version': 22, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 743804, '_primary_term': 1, 'status': 200}}, {'index': {'_index': 'profiles22', '_id': '6358398', '_version': 506, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 743805, '_primary_term': 1, 'status': 200}}, {'index': {'_index': 'profiles22', '_id': '29902541', '_version': 3960, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 743806, '_primary_term': 1, 'status': 200}}, {'index': {'_index': 'profiles22', '_id': '37854546', '_version': 1248, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 743807, '_primary_term': 1, 'status': 200}}, {'index': {'_index': 'profiles22', '_id': '37757457', '_version': 109, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 743808, '_primary_term': 1, 'status': 200}}, {'index': {'_index': 'profiles22', '_id': '3904331', '_version': 157, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 743809, '_primary_term': 1, 'status': 200}}, {'index': {'_index': 'profiles22', '_id': '6437309', '_version': 4427, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 743810, '_primary_term': 1, 'status': 200}}, {'index': {'_index': 'profiles22', '_id': '32990192', '_version': 10, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 743811, '_primary_term': 1, 'status': 200}}, {'index': {'_index': 'profiles22', '_id': '13325360', '_version': 103, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 743812, '_primary_term': 1, 'status': 200}}, {'index': {'_index': 'profiles22', '_id': '34297158', '_version': 9026, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 743813, '_primary_term': 1, 'status': 200}}, {'index': {'_index': 'profiles22', '_id': '32478595', '_version': 13114, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 743814, '_primary_term': 1, 'status': 200}}, {'index': {'_index': 'profiles22', '_id': '27337201', '_version': 10, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 743815, '_primary_term': 1, 'status': 200}}, {'index': {'_index': 'profiles22', '_id': '3129646', '_version': 255, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 743816, '_primary_term': 1, 'status': 200}}, {'index': {'_index': 'profiles22', '_id': '15185292', '_version': 417, 'result': 'updated', '_shards': { ...
